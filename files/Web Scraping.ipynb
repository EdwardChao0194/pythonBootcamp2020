# %%
import requests

# %%
import bs4

# %%
result = requests.get("http://www.example.com/")

# %%
type(result)
# Out:
# requests.models.Response

# %%
result.text
# Out:
# '<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n   
# ...

# %%
soup = bs4.BeautifulSoup(result.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Example Domain</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
# <body>
# <div>
# ...

# %%
soup.select('title')
# Out:
# [<title>Example Domain</title>]

# %%
soup.select('title')[0]
# Out:
# <title>Example Domain</title>

# %%
soup.select('title')[0].getText()
# Out:
# 'Example Domain'

# %%
site_paragraphs = soup.select('p')

# %%
site_paragraphs[0]
# Out:
# <p>This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.</p>

# %%
type(site_paragraphs)
# Out:
# bs4.element.ResultSet

# %%
res = requests.get('https://en.wikipedia.org/wiki/Dota_2')

# %%
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
soup.select('.toctext')
# Out:
# [<span class="toctext">Gameplay</span>,
#  <span class="toctext">Development</span>,
#  <span class="toctext"><i>Dota 2 Reborn</i></span>,
#  <span class="toctext">Release</span>,
#  <span class="toctext">Esports</span>,
#  <span class="toctext">Reception</span>,
#  <span class="toctext">Awards</span>,
#  <span class="toctext">Legacy</span>,
#  <span class="toctext">References</span>,
#  <span class="toctext">External links</span>]

# %%
first_item = soup.select('.toctext')

# %%
for item in soup.select('.toctext'):
    print(item.text)
# Out:
# Gameplay
# Development
# Dota 2 Reborn
# Release
# Esports
# Reception
# Awards
# Legacy
# References
# External links

# %%
soup.select('.thumbimage')
# Out:
# [<img alt="" class="thumbimage" data-file-height="237" data-file-width="421" decoding="async" height="124" src="//upload.wikimedia.org/wikipedia/en/thumb/5/53/Dota_2_Gameplay_Aug_2017.jpg/220px-Dota_2_Gameplay_Aug_2017.jpg" srcset="//upload.wikimedia.org/wikipedia/en/thumb/5/53/Dota_2_Gameplay_Aug_2017.jpg/330px-Dota_2_Gameplay_Aug_2017.jpg 1.5x, //upload.wikimedia.org/wikipedia/en/5/53/Dota_2_Gameplay_Aug_2017.jpg 2x" width="220"/>,
#  <img alt="" class="thumbimage" data-file-height="273" data-file-width="365" decoding="async" height="165" src="//upload.wikimedia.org/wikipedia/en/thumb/0/00/Dota_allstars_game.jpg/220px-Dota_allstars_game.jpg" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/00/Dota_allstars_game.jpg/330px-Dota_allstars_game.jpg 1.5x, //upload.wikimedia.org/wikipedia/en/0/00/Dota_allstars_game.jpg 2x" width="220"/>,
# ...

# %%
soup.select('.thumbimage')[6]
# Out:
# <img alt="" class="thumbimage" data-file-height="4272" data-file-width="2848" decoding="async" height="330" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/30/Dota_2_Juggernaut_cosplay.jpg/220px-Dota_2_Juggernaut_cosplay.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/30/Dota_2_Juggernaut_cosplay.jpg/330px-Dota_2_Juggernaut_cosplay.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/30/Dota_2_Juggernaut_cosplay.jpg/440px-Dota_2_Juggernaut_cosplay.jpg 2x" width="220"/>

# %%
computer = soup.select('.thumbimage')[6]

# %%
computer['src']
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/3/30/Dota_2_Juggernaut_cosplay.jpg/220px-Dota_2_Juggernaut_cosplay.jpg'

# %% [markdown]
# <img src="//upload.wikimedia.org/wikipedia/commons/thumb/3/30/Dota_2_Juggernaut_cosplay.jpg/220px-Dota_2_Juggernaut_cosplay.jpg">

# %%
image_link = requests.get('https://upload.wikimedia.org/wikipedia/commons/thumb/3/30/Dota_2_Juggernaut_cosplay.jpg/220px-Dota_2_Juggernaut_cosplay.jpg')

# %%
image_link.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xfe\x00TFile source: https://commons.wikimedia.org/wiki/File:Dota_2_Juggernaut_cosplay.jpg\xff\xdb\x00C\x00\x06\x04\x05\x06\x05\x04\x06\x06\x05\x06\x07\x07\x06\x08\n\x10\n\n\t\t\n\x14\x0e\x0f\x0c\x10\x17\x14\x18\x18\x17\x14\x16\x16\x1a\x1d%\x1f\x1a\x1b#\x1c\x16\x16 , #&\')*)\x19\x1f-0-(0%()(\xff\xdb\x00C\x01\x07\x07\x07\n\x08\n\x13\n\n\x13(\x1a\x16\x1a((((((((((((((((((((((((((((((((((((((((((((((((((\xff\xc0\x00\x11\x08\x01J\x00\xdc\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x01\x05\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x01\x02\x04\x05\x06\x00\x07\x08\xff\xc4\x00F\x10\x00\x02\x01\x03\x02\x03\x06\x02\x07\x06\x03\x05\x08\x03\x00\x00\x01\x02\x03\x00\x04\x11\x05!\x121A\x06\x13"Qaq2\x81\x07\x14B\x91\xa1\xb1\xc1#3Rr\xd1\xf0\x15b\xe1\x08$4C\x82%5S\x92\xa2\xb2\xc2\xf1\x16&D\xff\xc4\x00\x1b\x01\x00\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x
# ...

# %%
f = open('my_dota_2_hero.jpg','wb')

# %%
f.write(image_link.content)
# Out:
# 16878

# %%
f.close()
